# %%
# %pip install azure-storage-blob
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Requirement already satisfied: azure-storage-blob in /local_disk0/.ephemeral_nfs/envs/pythonEnv-35fcc659-156b-4544-bb39-f572880265fa/lib/python3.8/site-packages (12.13.0)
# Requirement already satisfied: msrest&gt;=0.6.21 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-35fcc659-156b-4544-bb39-f572880265fa/lib/python3.8/site-packages (from azure-storage-blob) (0.7.1)
# Requirement already satisfied: azure-core&lt;2.0.0,&gt;=1.23.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-35fcc659-156b-4544-bb39-f572880265fa/lib/python3.8/site-packages (from azure-storage-blob) (1.24.2)
# Requirement already satisfied: cryptography&gt;=2.1.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-35fcc659-156b-4544-bb39-f572880265fa/lib/python3.8/site-packages (from azure-storage-blob) (37.0.4)
# Requirement already satisfied: requests&gt;=2.18.4 in /databricks/python3/lib/python3.8/site-packages (from azure-core&lt;2.0.0,&gt;=1.23.1-&gt;azure-storage-blob) (2.25.1)
# Requirement already satisfied: typing-extensions&gt;=4.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-35fcc659-156b-4544-bb39-f572880265fa/lib/python3.8/site-packages (from azure-core&lt;2.0.0,&gt;=1.23.1-&gt;azure-storage-blob) (4.3.0)
# Requirement already satisfied: six&gt;=1.11.0 in /databricks/python3/lib/python3.8/site-packages (from azure-core&lt;2.0.0,&gt;=1.23.1-&gt;azure-storage-blob) (1.15.0)
# Requirement already satisfied: cffi&gt;=1.12 in /databricks/python3/lib/python3.8/site-packages (from cryptography&gt;=2.1.4-&gt;azure-storage-blob) (1.14.5)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.8/site-packages (from cffi&gt;=1.12-&gt;cryptography&gt;=2.1.4-&gt;azure-storage-blob) (2.20)
# Requirement already satisfied: isodate&gt;=0.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-35fcc659-156b-4544-bb39-f572880265fa/lib/python3.8/site-packages (from msrest&gt;=0.6.21-&gt;azure-storage-blob) (0.6.1)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from msrest&gt;=0.6.21-&gt;azure-storage-blob) (2020.12.5)
# Requirement already satisfied: requests-oauthlib&gt;=0.5.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-35fcc659-156b-4544-bb39-f572880265fa/lib/python3.8/site-packages (from msrest&gt;=0.6.21-&gt;azure-storage-blob) (1.3.1)
# Requirement already satisfied: urllib3&lt;1.27,&gt;=1.21.1 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.18.4-&gt;azure-core&lt;2.0.0,&gt;=1.23.1-&gt;azure-storage-blob) (1.25.11)
# Requirement already satisfied: idna&lt;3,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.18.4-&gt;azure-core&lt;2.0.0,&gt;=1.23.1-&gt;azure-storage-blob) (2.10)
# Requirement already satisfied: chardet&lt;5,&gt;=3.0.2 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.18.4-&gt;azure-core&lt;2.0.0,&gt;=1.23.1-&gt;azure-storage-blob) (4.0.0)
# Requirement already satisfied: oauthlib&gt;=3.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-35fcc659-156b-4544-bb39-f572880265fa/lib/python3.8/site-packages (from requests-oauthlib&gt;=0.5.0-&gt;msrest&gt;=0.6.21-&gt;azure-storage-blob) (3.2.0)
# Python interpreter will be restarted.
# </div>

# %%
import tarfile
import io
from pyspark.sql import functions as F
from azure.storage.blob import ContainerClient
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
conn_string= ""
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
client = ContainerClient.from_connection_string(conn_string, container_name='training-data')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Get train data filepaths
train_paths = [file.name for file in client.list_blobs()][0]
blob_client = client.get_blob_client(train_paths)
raw_file = blob_client.download_blob().readall()
paths = [path for path in str(raw_file).split('\\n')]
files = []
for name in paths:
    try: 
        folder, path = name.split('/')
        files.append(path)
    except ValueError:
        print(name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&#39;
# </div>

# %%
client = ContainerClient.from_connection_string(conn_string, container_name='updates')
blob_list = client.list_blobs()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Download train data
blob_list = enumerate(blob_list)
patents = []
false_examples = []
max_examples = 2000
c = 0

for i, blob_name in blob_list:
    try:
        print("Reading folder {}/{}".format(i, 92 ))
        blob_client = client.get_blob_client(blob_name)
        raw_file = blob_client.download_blob().readall()
        tar = tarfile.open(fileobj=io.BytesIO(raw_file))
        x_files = tar.getnames()
        for xml_file in x_files:
            x = xml_file.split('/')[1]
            if x in files:
                f = str(tar.extractfile(xml_file).read())
                patents.append((xml_file, f))
                print("######PATENT FOUND########")
                print(blob_name.name)
                print("##########################")
            elif c < max_examples:
                f = str(tar.extractfile(xml_file).read())
                false_examples.append((xml_file, f))
                c = c+1
                
    except Exception as E:
        print("ERROR {}. {}".format(blob_name.name, E))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Reading folder 0/92
# Reading folder 1/92
# Reading folder 2/92
# Reading folder 3/92
# Reading folder 4/92
# Reading folder 5/92
# Reading folder 6/92
# Reading folder 7/92
# Reading folder 8/92
# Reading folder 9/92
# Reading folder 10/92
# Reading folder 11/92
# Reading folder 12/92
# Reading folder 13/92
# Reading folder 14/92
# Reading folder 15/92
# Reading folder 16/92
# Reading folder 17/92
# Reading folder 18/92
# Reading folder 19/92
# Reading folder 20/92
# Reading folder 21/92
# Reading folder 22/92
# Reading folder 23/92
# Reading folder 24/92
# Reading folder 25/92
# Reading folder 26/92
# Reading folder 27/92
# Reading folder 28/92
# Reading folder 29/92
# Reading folder 30/92
# Reading folder 31/92
# Reading folder 32/92
# Reading folder 33/92
# Reading folder 34/92
# Reading folder 35/92
# Reading folder 36/92
# Reading folder 37/92
# Reading folder 38/92
# Reading folder 39/92
# Reading folder 40/92
# Reading folder 41/92
# Reading folder 42/92
# Reading folder 43/92
# Reading folder 44/92
# Reading folder 45/92
# Reading folder 46/92
# Reading folder 47/92
# Reading folder 48/92
# Reading folder 49/92
# Reading folder 50/92
# Reading folder 51/92
# Reading folder 52/92
# Reading folder 53/92
# Reading folder 54/92
# Reading folder 55/92
# Reading folder 56/92
# Reading folder 57/92
# Reading folder 58/92
# Reading folder 59/92
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001_120000.tgz
# ##########################
# ######PATENT FOUND########
# usapps_201935_back_100001

# %%
# Create Dataframe with train data
df = spark.createDataFrame(patents).toDF(*["file_name", "raw_txt"])
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: 2118</div>

# %%
df_false = spark.createDataFrame(false_examples).toDF(*["file_name", "raw_txt"])
df_false.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: 2000</div>

# %%
dbutils.fs.rm("/gustavo/train_data_raw/", True)
dbutils.fs.mkdirs("/gustavo/train_data_raw/good/")
dbutils.fs.mkdirs("/gustavo/train_data_raw/bad/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: True</div>

# %%
# Save raw data
df.write.parquet("/gustavo/train_data_raw/good/", mode="overwrite", compression="snappy")
df_false.write.parquet("/gustavo/train_data_raw/bad/", mode="overwrite", compression="snappy")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.read.parquet("/gustavo/train_data_raw/good/")
df_false = spark.read.parquet("/gustavo/train_data_raw/bad/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_false.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+
#            file_name|             raw_txt|
# +--------------------+--------------------+
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# back_100001_12000...|b&#39;&lt;?xml version=&#34;...|
# +--------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
# Add padding
def pad_sequence(features, max_len, t):
    pad = "0A" if t == "str" else -1
    features = features[1:]
    x = len(features)
    if x > max_len:
        features = features[0:max_len]
    else:
        extra= [pad]* (max_len - x)
        features = features + extra
    return features
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Gets all the classification-ipc items
def get_classification(txt):
    return txt.split("<classifications-ipcr>")[1].split("</classifications-ipcr>")[0].split("</classification-ipcr>") if "</classifications-ipcr>" in txt else ""

# Extracs all the values for an specified tag
def get_tags(class_list, tag, max_len, t):
    raw_tag = list(set([txt.split("<"+tag+">")[1].split("</"+tag+">")[0] if "</"+tag+">" in txt else "" for txt in class_list]))
    return pad_sequence(raw_tag, max_len, t)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Extract training fetures
get_classifications = udf(lambda x: get_classification(x))
get_levels = udf(lambda x: get_tags(x, "classification-level", 2, "str"))
get_sections = udf(lambda x: get_tags(x, "section", 2, "str"))
get_classes = udf(lambda x: get_tags(x, "class", 3, "int"))
get_subclasses = udf(lambda x: get_tags(x, "subclass", 3, "str"))
get_groups = udf(lambda x: get_tags(x, "main-group", 4, "int"))
get_subgroups = udf(lambda x: get_tags(x, "subgroup", 4, "int"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# DF with true examples
df = df.withColumn("classification", get_classifications("raw_txt"))
df = df.withColumn("levels", get_levels("classification"))
df = df.withColumn("sections", get_sections("classification"))
df = df.withColumn("clasess", get_classes("classification"))
df = df.withColumn("subclasess", get_subclasses("classification"))
df = df.withColumn("groups", get_groups("classification"))
df = df.withColumn("subgroups", get_subgroups("classification"))
df = df.withColumn("target", F.lit(0))
df = df.drop("raw_txt", "classification")

# DF with false examples
df_false = df_false.withColumn("classification", get_classifications("raw_txt"))
df_false = df_false.withColumn("levels", get_levels("classification"))
df_false = df_false.withColumn("sections", get_sections("classification"))
df_false = df_false.withColumn("clasess", get_classes("classification"))
df_false = df_false.withColumn("subclasess", get_subclasses("classification"))
df_false = df_false.withColumn("groups", get_groups("classification"))
df_false = df_false.withColumn("subgroups", get_subgroups("classification"))
df_false = df_false.withColumn("target", F.lit(1))
df_false = df_false.drop("raw_txt", "classification")

df = df.union(df_false)
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-------+--------+------------+-----------+-----------------+------------------+------+
#            file_name| levels|sections|     clasess| subclasess|           groups|         subgroups|target|
# +--------------------+-------+--------+------------+-----------+-----------------+------------------+------+
# back_140001_16000...|[A, 0A]|  [H, G]|[06, 04, -1]| [L, F, 0A]|    [, 1, 15, -1]|[00, 177, 911, -1]|     0|
# back_140001_16000...|[A, 0A]| [G, 0A]|[01, -1, -1]|[R, 0A, 0A]| [21, -1, -1, -1]|  [00, -1, -1, -1]|     0|
# back_140001_16000...|[A, 0A]|  [H, G]|[06, 04, -1]| [L, F, 0A]|  [12, 9, 11, 15]|   [, 34, 30, 911]|     0|
# back_140001_16000...|[A, 0A]| [H, 0A]|[02, -1, -1]| [, 0A, 0A]|  [3, -1, -1, -1]|    [, -1, -1, -1]|     0|
# back_140001_16000...|[A, 0A]| [A, 0A]|[47, -1, -1]|[C, 0A, 0A]| [21, -1, -1, -1]|  [00, 04, -1, -1]|     0|
# back_140001_16000...|[A, 0A]| [A, 0A]|[01, -1, -1]|[K, 0A, 0A]| [63, -1, -1, -1]|  [04, -1, -1, -1]|     0|
# back_140001_16000...|[A, 0A]| [G, 0A]|[06, -1, -1]|[K, 0A, 0A]|  [7, -1, -1, -1]|    [, -1, -1, -1]|     0|
# back_140001_16000...|[A, 0A]|  [F, G]|  [, 05, -1]|  [B, F, D]|[17, 011, 23, 15]|  [00, 02, 19, -1]|     0|
# back_140001_16000...|[A, 0A]| [H, 0A]|[03, -1, -1]|[K, 0A, 0A]| [17, -1, -1, -1]|   [, 725, -1, -1]|     0|
# back_140001_16000...|[A, 0A]| [H, 0A]|[02, 03, -1]| [H, K, 0A]|  [17, 3, -1, -1]| [687, 13, 00, 16]|     0|
# back_140001_16000...|[A, 0A]| [H, 0A]|[02, 03, -1]| [K, M, 0A]|   [1, 17, 5, -1]| [13, 00, 44, 257]|     0|
# back_140001_16000...|[A, 0A]|  [H, G]|[01, 05, -1]|[B, 0A, 0A]|   [, 11, 33, -1]|  [02, 14, 08, -1]|     0|
# back_140001_16000...|[A, 0A]|  [H, G]|[01, 05, -1]| [B, V, 0A]|  [8, 37, 11, 33]|    [, 14, 08, 02]|     0|
# back_140001_16000...|[A, 0A]| [H, 0A]|[04, -1, -1]|[W, 0A, 0A]| [52, -1, -1, -1]|  [02, -1, -1, -1]|     0|
# back_140001_16000...|[A, 0A]|  [B, C]|[28, 04, -1]|[B, 0A, 0A]|   [1, 35, 3, -1]|  [02, 06, 22, -1]|     0|
# back_140001_16000...|[A, 0A]|  [H, F]|[28, 05, -1]|  [K, F, D]|  [23, 7, 27, -1]|  [30, 00, 20, 19]|     0|
# back_140001_16000...|[A, 0A]|  [A, F]|  [61, 62, ]|  [B, K, M]|    [31, 7, , -1]|  [02, 00, -1, -1]|     0|
# back_140001_16000...|[A, 0A]|  [H, E]|[06, 04, 05]| [B, Q, 0A]|  [9, 37, -1, -1]|  [32, 00, 02, 68]|     0|
# back_140001_16000...|[A, 0A]| [E, 0A]|[06, -1, -1]|[B, 0A, 0A]|  [9, -1, -1, -1]|  [68, -1, -1, -1]|     0|
# back_140001_16000...|[A, 0A]| [F, 0A]|  [, -1, -1]|[H, 0A, 0A]|  [9, -1, -1, -1]|    [18, , -1, -1]|     0|
# +--------------------+-------+--------+------------+-----------+-----------------+------------------+------+
# only showing top 20 rows
#
# </div>

# %%
# Save train data
dbutils.fs.mkdirs("/gustavo/train_data/")
df.write.parquet("/gustavo/train_data/", mode="overwrite", compression="snappy")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
